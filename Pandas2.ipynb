# %% [markdown]
# <a href="https://colab.research.google.com/github/pratik-chakraborty10/Pandas_for_ML/blob/main/Pandas2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
iris_df=pd.read_csv("imdb.csv")

# %%
data_frame=iris_df.copy()
data_frame.head(3)
# Out:
#    lister-item-index       lister-item-header certificate runtime  \
# 0                1.0          Stranger Things          15  60 min
# 1                2.0           13 Reasons Why          18  60 min
# 2                3.0  Orange Is the New Black          18  59 min
#
#                       genre  rating      votes
# 0    Drama, Fantasy, Horror     8.7  1,327,188
# 1  Drama, Mystery, Thriller     7.5    314,321
# 2      Comedy, Crime, Drama     8.0    319,342

# %%
data_frame.drop(0)#to drop any row just give the label value.
data_frame.head(3)#but after dropping the 0th label row appears same because in python we have to use inplace->true
# Out:
#    lister-item-index       lister-item-header certificate runtime  \
# 0                1.0          Stranger Things          15  60 min
# 1                2.0           13 Reasons Why          18  60 min
# 2                3.0  Orange Is the New Black          18  59 min
#
#                       genre  rating      votes
# 0    Drama, Fantasy, Horror     8.7  1,327,188
# 1  Drama, Mystery, Thriller     7.5    314,321
# 2      Comedy, Crime, Drama     8.0    319,342

# %%
data_frame.drop(1,inplace=True)

# %%
new_df=data_frame.drop(2)#another way to drop
new_df.head(5)
# Out:
#    lister-item-index lister-item-header certificate    runtime  \
# 3                4.0       Black Mirror          18     60 min
# 4                5.0        Money Heist          15     60 min
# 5                6.0            Lucifer          15  4,393 min
# 6                7.0             Narcos          15     50 min
# 7                8.0          Daredevil          15     60 min
#
#                      genre  rating    votes
# 3   Drama, Mystery, Sci-Fi     8.7  636,319
# 4     Action, Crime, Drama     8.2  529,086
# 5    Crime, Drama, Fantasy     8.1  354,155
# 6  Biography, Crime, Drama     8.8  467,909
# 7     Action, Crime, Drama     8.6  472,940

# %%
new_df.index#showing index
# Out:
# RangeIndex(start=3, stop=80, step=1)

# %%
new_df.index[0] #at index 0 ->label 3 exists.
# Out:
# 3

# %%
new_df.drop(new_df.index[0],inplace=True)#drop label at index 0 position.
new_df.head()
# Out:
#     lister-item-index            lister-item-header certificate runtime  \
# 8                 9.0                        Sense8          15  60 min
# 9                10.0                 Jessica Jones          15  56 min
# 10               11.0                House of Cards          18  50 min
# 11               12.0  The End of the F***ing World          15  25 min
# 12               13.0                          Dark          15  60 min
#
#                        genre  rating    votes
# 8     Drama, Mystery, Sci-Fi     8.2  162,528
# 9       Action, Crime, Drama     7.9  226,187
# 10                     Drama     8.6  529,463
# 11  Adventure, Comedy, Crime     8.0  218,483
# 12     Crime, Drama, Mystery     8.7  440,321

# %%
new_df.certificate > "15" #check condition
# Out:
# 8     False
# 9     False
# 10     True
# 11    False
# 12    False
#       ...
# 75    False
# 76    False
# 77    False
# 78    False
# 79     True
# Name: certificate, Length: 72, dtype: bool
