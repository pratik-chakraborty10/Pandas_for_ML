# %% [markdown]
# <a href="https://colab.research.google.com/github/pratik-chakraborty10/Pandas_for_ML/blob/main/Pandas1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
iris_df=pd.read_csv("imdb.csv")#read csv dataset file by this method.
print(iris_df)
print(type(iris_df))#DataFrame->like 2D array.
# Out:
#     lister-item-index       lister-item-header certificate runtime  \
# 0                 1.0          Stranger Things          15  60 min
# 1                 2.0           13 Reasons Why          18  60 min
# 2                 3.0  Orange Is the New Black          18  59 min
# 3                 4.0             Black Mirror          18  60 min
# 4                 5.0              Money Heist          15  60 min
# ..                ...                      ...         ...     ...
# 75               76.0          F Is for Family          15  30 min
# 76               77.0                The Ranch          15  30 min
# 77               78.0          American Vandal          15  34 min
# 78               79.0               Dead to Me          15  30 min
# 79               80.0                Quicksand          18  45 min
#
#                        genre  rating      votes
# 0     Drama, Fantasy, Horror     8.7  1,327,188
# 1   Drama, Mystery, Thriller     7.5    314,321
# ...

# %%
data_frame=iris_df.copy()# not to  work on our uploaded dataset

# %%
data_frame.head()# data in more formatting order
data_frame.head(10)#show first 10 entry
data_frame.tail(5)#show last 5 entry
# Out:
#     lister-item-index lister-item-header certificate runtime  \
# 75               76.0    F Is for Family          15  30 min
# 76               77.0          The Ranch          15  30 min
# 77               78.0    American Vandal          15  34 min
# 78               79.0         Dead to Me          15  30 min
# 79               80.0          Quicksand          18  45 min
#
#                        genre  rating   votes
# 75  Animation, Comedy, Drama     8.0  41,074
# 76    Comedy, Drama, Western     7.5  42,401
# 77      Comedy, Crime, Drama     8.1  32,985
# 78      Comedy, Crime, Drama     7.9  99,440
# 79     Crime, Drama, Mystery     7.4  25,507

# %%
print(data_frame.shape)#showing the number of rows and coloumns
# Out:
# (80, 7)

# %%
print(data_frame.dtypes)#showing data type of every columns
# Out:
# lister-item-index     float64
# lister-item-header     object
# certificate            object
# runtime                object
# genre                  object
# rating                float64
# votes                  object
# dtype: object

# %%
data_frame["votes"]#accesing data_frame's cols
data_frame.votes#same usecase.
# Out:
# 0     1,327,188
# 1       314,321
# 2       319,342
# 3       636,319
# 4       529,086
#         ...
# 75       41,074
# 76       42,401
# 77       32,985
# 78       99,440
# 79       25,507
# Name: votes, Length: 80, dtype: object

# %%
data_frame.isnull()
data_frame.isnull().sum()
# Out:
# lister-item-index     0
# lister-item-header    0
# certificate           0
# runtime               0
# genre                 0
# rating                0
# votes                 0
# dtype: int64

# %%
data_frame.iloc[0:3,0:4]#showing first 3 rows and 4 coloumns
# Out:
#    lister-item-index       lister-item-header certificate runtime
# 0                1.0          Stranger Things          15  60 min
# 1                2.0           13 Reasons Why          18  60 min
# 2                3.0  Orange Is the New Black          18  59 min
