# %% [markdown]
# <a href="https://colab.research.google.com/github/pratik-chakraborty10/Pandas_for_ML/blob/main/Pandas3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
iris_df=pd.read_csv("imdb.csv")
data_frame=iris_df.copy()
#print(data_frame)

# %%
new_df=data_frame.copy()

# %%
new_df.describe()
# Out:
#        lister-item-index    rating
# count            80.0000  80.00000
# mean             40.5000   7.72000
# std              23.2379   0.71235
# min               1.0000   5.90000
# 25%              20.7500   7.20000
# 50%              40.5000   7.80000
# 75%              60.2500   8.22500
# max              80.0000   8.80000

# %%
new_df[new_df.certificate > "18"].describe()
# Out:
#        lister-item-index    rating
# count           3.000000  3.000000
# mean           47.666667  7.000000
# std            17.097758  0.608276
# min            28.000000  6.600000
# 25%            42.000000  6.650000
# 50%            56.000000  6.700000
# 75%            57.500000  7.200000
# max            59.000000  7.700000

# %%
new_df.head(5)
# Out:
#    lister-item-index       lister-item-header certificate runtime  \
# 0                1.0          Stranger Things          15  60 min
# 1                2.0           13 Reasons Why          18  60 min
# 2                3.0  Orange Is the New Black          18  59 min
# 3                4.0             Black Mirror          18  60 min
# 4                5.0              Money Heist          15  60 min
#
#                       genre  rating      votes
# 0    Drama, Fantasy, Horror     8.7  1,327,188
# 1  Drama, Mystery, Thriller     7.5    314,321
# 2      Comedy, Crime, Drama     8.0    319,342
# 3    Drama, Mystery, Sci-Fi     8.7    636,319
# 4      Action, Crime, Drama     8.2    529,086

# %%
new_df[new_df.rating >= 8.5].describe()
# Out:
#        lister-item-index     rating
# count          15.000000  15.000000
# mean           30.000000   8.626667
# std            23.170178   0.103280
# min             1.000000   8.500000
# 25%             9.500000   8.550000
# 50%            30.000000   8.600000
# 75%            41.000000   8.700000
# max            73.000000   8.800000

# %%
print(new_df.head())
print(new_df.iloc[0]) #works on index or position
#print(new_df.loc[0]) #works on labels as label 0 does  exist it not give any error.
#new_df.drop(0,inplace=True)#dropping row
#print(new_df.loc[0])# now it shows error because we drop the 0th label.
print(new_df.loc[5])
# Out:
#    lister-item-index       lister-item-header certificate    runtime  \
# 1                2.0           13 Reasons Why          18     60 min
# 2                3.0  Orange Is the New Black          18     59 min
# 3                4.0             Black Mirror          18     60 min
# 4                5.0              Money Heist          15     60 min
# 5                6.0                  Lucifer          15  4,393 min
#
#                       genre  rating    votes
# 1  Drama, Mystery, Thriller     7.5  314,321
# 2      Comedy, Crime, Drama     8.0  319,342
# 3    Drama, Mystery, Sci-Fi     8.7  636,319
# 4      Action, Crime, Drama     8.2  529,086
# 5     Crime, Drama, Fantasy     8.1  354,155
# lister-item-index                          2.0
# lister-item-header              13 Reasons Why
# certificate                                 18
# runtime                                 60 min
# genre                 Drama, Mystery, Thriller
# ...

# %%
new_df.head(2)
# Out:
#    lister-item-index       lister-item-header certificate runtime  \
# 1                2.0           13 Reasons Why          18  60 min
# 2                3.0  Orange Is the New Black          18  59 min
#
#                       genre  rating    votes
# 1  Drama, Mystery, Thriller     7.5  314,321
# 2      Comedy, Crime, Drama     8.0  319,342

# %%
new_df.loc[0]=[2.0,"Archer","16","57min","Dedication,Love,Thriller",6.7,120000] #reassigning the label 0
new_df.head() #but in the head it not shows label 0
new_df.tail() #in the tail it shows label 0
# Out:
#     lister-item-index lister-item-header certificate runtime  \
# 76               77.0          The Ranch          15  30 min
# 77               78.0    American Vandal          15  34 min
# 78               79.0         Dead to Me          15  30 min
# 79               80.0          Quicksand          18  45 min
# 0                 2.0             Archer          16   57min
#
#                        genre  rating   votes
# 76    Comedy, Drama, Western     7.5  42,401
# 77      Comedy, Crime, Drama     8.1  32,985
# 78      Comedy, Crime, Drama     7.9  99,440
# 79     Crime, Drama, Mystery     7.4  25,507
# 0   Dedication,Love,Thriller     6.7  120000

# %%
new_df.reset_index(drop=True,inplace=True) #reassigning the label by using reset_index method.
#if we remove the [drop=True] then multiple indexes are create.

# %%
print(new_df.head(5)) #successfully get the drop label
# Out:
#    lister-item-index       lister-item-header certificate    runtime  \
# 0                2.0           13 Reasons Why          18     60 min
# 1                3.0  Orange Is the New Black          18     59 min
# 2                4.0             Black Mirror          18     60 min
# 3                5.0              Money Heist          15     60 min
# 4                6.0                  Lucifer          15  4,393 min
#
#                       genre  rating    votes
# 0  Drama, Mystery, Thriller     7.5  314,321
# 1      Comedy, Crime, Drama     8.0  319,342
# 2    Drama, Mystery, Sci-Fi     8.7  636,319
# 3      Action, Crime, Drama     8.2  529,086
# 4     Crime, Drama, Fantasy     8.1  354,155

# %%
new_df.drop(0,inplace=True)

# %%
new_df.reset_index(inplace=True) #new index coloumn created.

# %%
print(new_df.head())
# Out:
#    index  lister-item-index       lister-item-header certificate    runtime  \
# 0      1                3.0  Orange Is the New Black          18     59 min
# 1      2                4.0             Black Mirror          18     60 min
# 2      3                5.0              Money Heist          15     60 min
# 3      4                6.0                  Lucifer          15  4,393 min
# 4      5                7.0                   Narcos          15     50 min
#
#                      genre  rating    votes
# 0     Comedy, Crime, Drama     8.0  319,342
# 1   Drama, Mystery, Sci-Fi     8.7  636,319
# 2     Action, Crime, Drama     8.2  529,086
# 3    Crime, Drama, Fantasy     8.1  354,155
# 4  Biography, Crime, Drama     8.8  467,909

# %%
new_df.drop(columns="index",inplace=True) #deleting a particular column

# %%
print(new_df.head())
# Out:
#    lister-item-index       lister-item-header certificate    runtime  \
# 0                3.0  Orange Is the New Black          18     59 min
# 1                4.0             Black Mirror          18     60 min
# 2                5.0              Money Heist          15     60 min
# 3                6.0                  Lucifer          15  4,393 min
# 4                7.0                   Narcos          15     50 min
#
#                      genre  rating    votes
# 0     Comedy, Crime, Drama     8.0  319,342
# 1   Drama, Mystery, Sci-Fi     8.7  636,319
# 2     Action, Crime, Drama     8.2  529,086
# 3    Crime, Drama, Fantasy     8.1  354,155
# 4  Biography, Crime, Drama     8.8  467,909

# %%
new_df.describe()
# Out:
#        lister-item-index     rating
# count          79.000000  79.000000
# mean           41.000000   7.697468
# std            22.949219   0.716826
# min             2.000000   5.900000
# 25%            21.500000   7.200000
# 50%            41.000000   7.800000
# 75%            60.500000   8.200000
# max            80.000000   8.800000

# %%
del new_df["lister-item-index"] #another way of deleting a column

# %%
new_df.head() #lister-item-index->deleted successfully.
# Out:
#         lister-item-header certificate    runtime                    genre  \
# 0  Orange Is the New Black          18     59 min     Comedy, Crime, Drama
# 1             Black Mirror          18     60 min   Drama, Mystery, Sci-Fi
# 2              Money Heist          15     60 min     Action, Crime, Drama
# 3                  Lucifer          15  4,393 min    Crime, Drama, Fantasy
# 4                   Narcos          15     50 min  Biography, Crime, Drama
#
#    rating    votes
# 0     8.0  319,342
# 1     8.7  636,319
# 2     8.2  529,086
# 3     8.1  354,155
# 4     8.8  467,909

# %%
new_df["color"]="black" #adding a new column

# %%
new_df.head() #new column added successfully.
# Out:
#         lister-item-header certificate    runtime                    genre  \
# 0  Orange Is the New Black          18     59 min     Comedy, Crime, Drama
# 1             Black Mirror          18     60 min   Drama, Mystery, Sci-Fi
# 2              Money Heist          15     60 min     Action, Crime, Drama
# 3                  Lucifer          15  4,393 min    Crime, Drama, Fantasy
# 4                   Narcos          15     50 min  Biography, Crime, Drama
#
#    rating    votes  color
# 0     8.0  319,342  black
# 1     8.7  636,319  black
# 2     8.2  529,086  black
# 3     8.1  354,155  black
# 4     8.8  467,909  black
