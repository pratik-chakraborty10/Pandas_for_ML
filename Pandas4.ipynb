# %% [markdown]
# <a href="https://colab.research.google.com/github/pratik-chakraborty10/Pandas_for_ML/blob/main/Pandas4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
iris_df=pd.read_csv("imdb.csv")
data_frame=iris_df.copy()
data_frame.head()
# Out:
#    lister-item-index       lister-item-header certificate runtime  \
# 0                1.0          Stranger Things          15  60 min
# 1                2.0           13 Reasons Why          18  60 min
# 2                3.0  Orange Is the New Black          18  59 min
# 3                4.0             Black Mirror          18  60 min
# 4                5.0              Money Heist          15  60 min
#
#                       genre  rating      votes
# 0    Drama, Fantasy, Horror     8.7  1,327,188
# 1  Drama, Mystery, Thriller     7.5    314,321
# 2      Comedy, Crime, Drama     8.0    319,342
# 3    Drama, Mystery, Sci-Fi     8.7    636,319
# 4      Action, Crime, Drama     8.2    529,086

# %%
data_frame.describe()
# Out:
#        lister-item-index    rating
# count            80.0000  80.00000
# mean             40.5000   7.72000
# std              23.2379   0.71235
# min               1.0000   5.90000
# 25%              20.7500   7.20000
# 50%              40.5000   7.80000
# 75%              60.2500   8.22500
# max              80.0000   8.80000

# %%
data_frame.iloc[2:3,2:4]=np.nan #nan is similar like null
data_frame.head()
# Out:
#    lister-item-index       lister-item-header certificate runtime  \
# 0                1.0          Stranger Things          15  60 min
# 1                2.0           13 Reasons Why          18  60 min
# 2                3.0  Orange Is the New Black         NaN     NaN
# 3                4.0             Black Mirror          18  60 min
# 4                5.0              Money Heist          15  60 min
#
#                       genre  rating      votes
# 0    Drama, Fantasy, Horror     8.7  1,327,188
# 1  Drama, Mystery, Thriller     7.5    314,321
# 2      Comedy, Crime, Drama     8.0    319,342
# 3    Drama, Mystery, Sci-Fi     8.7    636,319
# 4      Action, Crime, Drama     8.2    529,086

# %%
data_frame.dropna(inplace=True) # Nan consisting row or coloumn deletes.
data_frame.head()
# Out:
#    lister-item-index lister-item-header certificate    runtime  \
# 0                1.0    Stranger Things          15     60 min
# 1                2.0     13 Reasons Why          18     60 min
# 3                4.0       Black Mirror          18     60 min
# 4                5.0        Money Heist          15     60 min
# 5                6.0            Lucifer          15  4,393 min
#
#                       genre  rating      votes
# 0    Drama, Fantasy, Horror     8.7  1,327,188
# 1  Drama, Mystery, Thriller     7.5    314,321
# 3    Drama, Mystery, Sci-Fi     8.7    636,319
# 4      Action, Crime, Drama     8.2    529,086
# 5     Crime, Drama, Fantasy     8.1    354,155

# %%
data_frame.reset_index(drop=True,inplace=True)
data_frame.head()
# Out:
#    lister-item-index lister-item-header certificate    runtime  \
# 0                1.0    Stranger Things          15     60 min
# 1                2.0     13 Reasons Why          18     60 min
# 2                4.0       Black Mirror          18     60 min
# 3                5.0        Money Heist          15     60 min
# 4                6.0            Lucifer          15  4,393 min
#
#                       genre  rating      votes
# 0    Drama, Fantasy, Horror     8.7  1,327,188
# 1  Drama, Mystery, Thriller     7.5    314,321
# 2    Drama, Mystery, Sci-Fi     8.7    636,319
# 3      Action, Crime, Drama     8.2    529,086
# 4     Crime, Drama, Fantasy     8.1    354,155

# %%
data_frame.iloc[2:3,2:4]=np.nan
data_frame.head()
# Out:
#    lister-item-index lister-item-header certificate    runtime  \
# 0                1.0    Stranger Things          15     60 min
# 1                2.0     13 Reasons Why          18     60 min
# 2                4.0       Black Mirror         NaN        NaN
# 3                5.0        Money Heist          15     60 min
# 4                6.0            Lucifer          15  4,393 min
#
#                       genre  rating      votes
# 0    Drama, Fantasy, Horror     8.7  1,327,188
# 1  Drama, Mystery, Thriller     7.5    314,321
# 2    Drama, Mystery, Sci-Fi     8.7    636,319
# 3      Action, Crime, Drama     8.2    529,086
# 4     Crime, Drama, Fantasy     8.1    354,155

# %%
data_frame.iloc[2:7,2:8]=np.nan
data_frame.head()
# Out:
#    lister-item-index lister-item-header certificate runtime  \
# 0                1.0    Stranger Things          15  60 min
# 1                2.0     13 Reasons Why          18  60 min
# 2                4.0       Black Mirror         NaN     NaN
# 3                5.0        Money Heist         NaN     NaN
# 4                6.0            Lucifer         NaN     NaN
#
#                       genre  rating      votes
# 0    Drama, Fantasy, Horror     8.7  1,327,188
# 1  Drama, Mystery, Thriller     7.5    314,321
# 2                       NaN     NaN        NaN
# 3                       NaN     NaN        NaN
# 4                       NaN     NaN        NaN

# %%
data_frame.rating.fillna(data_frame.rating.mean(),inplace=True)
data_frame.head()
# Out:
#    lister-item-index lister-item-header certificate runtime  \
# 0                1.0    Stranger Things          15  60 min
# 1                2.0     13 Reasons Why          18  60 min
# 2                4.0       Black Mirror         NaN     NaN
# 3                5.0        Money Heist         NaN     NaN
# 4                6.0            Lucifer         NaN     NaN
#
#                       genre    rating      votes
# 0    Drama, Fantasy, Horror  8.700000  1,327,188
# 1  Drama, Mystery, Thriller  7.500000    314,321
# 2                       NaN  7.664865        NaN
# 3                       NaN  7.664865        NaN
# 4                       NaN  7.664865        NaN

# %%
temp=data_frame[data_frame.rating == 7.664865]
data_frame.votes.fillna(temp.rating.mean(),inplace=True)
data_frame.head()
# Out:
#    lister-item-index lister-item-header certificate runtime  \
# 0                1.0    Stranger Things          15  60 min
# 1                2.0     13 Reasons Why          18  60 min
# 2                4.0       Black Mirror         NaN     NaN
# 3                5.0        Money Heist         NaN     NaN
# 4                6.0            Lucifer         NaN     NaN
#
#                       genre    rating      votes
# 0    Drama, Fantasy, Horror  8.700000  1,327,188
# 1  Drama, Mystery, Thriller  7.500000    314,321
# 2                       NaN  7.664865        NaN
# 3                       NaN  7.664865        NaN
# 4                       NaN  7.664865        NaN
